# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data218 = pd.read_csv("data218.csv")
data218
# Out:
#       batch_no classifier  accuracy  recall_0  recall_4  precision_0  \
# 0            1         PA   0.66950  0.631420  0.707051     0.680043
# 1            1         NB   0.78350  0.784491  0.782522     0.780561
# 2            1        SGD   0.66950  0.577039  0.760675     0.703931
# 3            2         PA   0.69450  0.701449  0.687047     0.706226
# 4            2         NB   0.78650  0.800000  0.772021     0.790076
# ...        ...        ...       ...       ...       ...          ...
# 5200       189         NB   0.79250  0.782554  0.802225     0.794608
# 5201       189        SGD   0.75250  0.696587  0.807169     0.779349
# 5202       190         PA   0.69125  0.697703  0.684347     0.702801
# 5203       190         NB   0.80375  0.812576  0.794308     0.808664
# 5204       190        SGD   0.74375  0.680774  0.811125     0.794076
#
#       precision_4      f1_0      f1_4  batch_size
# 0        0.660482  0.654830  0.682974       10000
# ...

# %%
data218.accuracy.max()
# Out:
# 0.915

# %%
no = ["2**18"]*5205

# %%
no
# Out:
# ['2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
#  '2**18',
# ...

# %%
data218["features"]=no

# %%
data218
# Out:
#       batch_no classifier  accuracy  recall_0  recall_4  precision_0  \
# 0            1         PA   0.66950  0.631420  0.707051     0.680043
# 1            1         NB   0.78350  0.784491  0.782522     0.780561
# 2            1        SGD   0.66950  0.577039  0.760675     0.703931
# 3            2         PA   0.69450  0.701449  0.687047     0.706226
# 4            2         NB   0.78650  0.800000  0.772021     0.790076
# ...        ...        ...       ...       ...       ...          ...
# 5200       189         NB   0.79250  0.782554  0.802225     0.794608
# 5201       189        SGD   0.75250  0.696587  0.807169     0.779349
# 5202       190         PA   0.69125  0.697703  0.684347     0.702801
# 5203       190         NB   0.80375  0.812576  0.794308     0.808664
# 5204       190        SGD   0.74375  0.680774  0.811125     0.794076
#
#       precision_4      f1_0      f1_4  batch_size features
# 0        0.660482  0.654830  0.682974       10000    2**18
# ...

# %%
data212 = pd.read_csv("data212.csv")
data212
# Out:
#       batch_no classifier  accuracy  recall_0  recall_4  precision_0  \
# 0            1         PA    0.6325  0.676190  0.584211     0.642534
# 1            1         NB    0.8075  0.800000  0.815789     0.827586
# 2            1        SGD    0.5925  0.561905  0.626316     0.624339
# 3            2         PA    0.6825  0.715736  0.650246     0.665094
# 4            2         NB    0.8150  0.827411  0.802956     0.802956
# ...        ...        ...       ...       ...       ...          ...
# 5200       151         NB    0.7235  0.686294  0.759606     0.734783
# 5201       151        SGD    0.7200  0.654822  0.783251     0.745665
# 5202       152         PA    0.6900  0.678537  0.702393     0.711403
# 5203       152         NB    0.7305  0.743022  0.716961     0.739464
# 5204       152        SGD    0.7385  0.704524  0.775234     0.772152
#
#       precision_4      f1_0      f1_4  batch_size
# 0        0.620112  0.658933  0.601626        2000
# ...

# %%
no = ["2**12"]*5205

# %%
data212["features"]=no
data212
# Out:
#       batch_no classifier  accuracy  recall_0  recall_4  precision_0  \
# 0            1         PA    0.6325  0.676190  0.584211     0.642534
# 1            1         NB    0.8075  0.800000  0.815789     0.827586
# 2            1        SGD    0.5925  0.561905  0.626316     0.624339
# 3            2         PA    0.6825  0.715736  0.650246     0.665094
# 4            2         NB    0.8150  0.827411  0.802956     0.802956
# ...        ...        ...       ...       ...       ...          ...
# 5200       151         NB    0.7235  0.686294  0.759606     0.734783
# 5201       151        SGD    0.7200  0.654822  0.783251     0.745665
# 5202       152         PA    0.6900  0.678537  0.702393     0.711403
# 5203       152         NB    0.7305  0.743022  0.716961     0.739464
# 5204       152        SGD    0.7385  0.704524  0.775234     0.772152
#
#       precision_4      f1_0      f1_4  batch_size features
# 0        0.620112  0.658933  0.601626        2000    2**12
# ...

# %%
data212.accuracy.max()
# Out:
# 0.86

# %%
total = [data212 , data218]

# %%
df = pd.concat(total)

# %%
df
# Out:
#       batch_no classifier  accuracy  recall_0  recall_4  precision_0  \
# 0            1         PA   0.63250  0.676190  0.584211     0.642534
# 1            1         NB   0.80750  0.800000  0.815789     0.827586
# 2            1        SGD   0.59250  0.561905  0.626316     0.624339
# 3            2         PA   0.68250  0.715736  0.650246     0.665094
# 4            2         NB   0.81500  0.827411  0.802956     0.802956
# ...        ...        ...       ...       ...       ...          ...
# 5200       189         NB   0.79250  0.782554  0.802225     0.794608
# 5201       189        SGD   0.75250  0.696587  0.807169     0.779349
# 5202       190         PA   0.69125  0.697703  0.684347     0.702801
# 5203       190         NB   0.80375  0.812576  0.794308     0.808664
# 5204       190        SGD   0.74375  0.680774  0.811125     0.794076
#
#       precision_4      f1_0      f1_4  batch_size features
# 0        0.620112  0.658933  0.601626        2000    2**12
# ...

# %%
class212 = data212.groupby('batch_size')

# %%
class212.describe()
# Out:
#            batch_no                                                        \
#               count   mean         std  min     25%    50%     75%    max
# batch_size
# 2000         2280.0  380.5  219.441041  1.0  190.75  380.5  570.25  760.0
# 4000         1140.0  190.5  109.744315  1.0   95.75  190.5  285.25  380.0
# 6000          759.0  127.0   73.082398  1.0   64.00  127.0  190.00  253.0
# 8000          570.0   95.5   54.895691  1.0   48.00   95.5  143.00  190.0
# 10000         456.0   76.5   43.925862  1.0   38.75   76.5  114.25  152.0
#
#            accuracy            ...      f1_0              f1_4            \
#               count      mean  ...       75%       max   count      mean
# batch_size                     ...
# 2000         2280.0  0.724034  ...  0.785948  0.870370  2280.0  0.728063
# 4000         1140.0  0.715938  ...  0.750074  0.813810  1140.0  0.720167
# 6000          759.0  0.711178  ...  0.735218  0.790769   759.0  0.716393
# ...

# %%
data212[data212.batch_size == 2000]
# Out:
#       batch_no classifier  accuracy  recall_0  recall_4  precision_0  \
# 0            1         PA    0.6325  0.676190  0.584211     0.642534
# 1            1         NB    0.8075  0.800000  0.815789     0.827586
# 2            1        SGD    0.5925  0.561905  0.626316     0.624339
# 3            2         PA    0.6825  0.715736  0.650246     0.665094
# 4            2         NB    0.8150  0.827411  0.802956     0.802956
# ...        ...        ...       ...       ...       ...          ...
# 2275       759         NB    0.8150  0.821596  0.807487     0.829384
# 2276       759        SGD    0.7400  0.713615  0.770053     0.779487
# 2277       760         PA    0.6100  0.547739  0.671642     0.622857
# 2278       760         NB    0.8025  0.783920  0.820896     0.812500
# 2279       760        SGD    0.7300  0.663317  0.796020     0.763006
#
#       precision_4      f1_0      f1_4  batch_size features
# 0        0.620112  0.658933  0.601626        2000    2**12
# ...

# %%
plt.figure(figsize=(16,5))
bsize=2000
x = data212[data212.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^12')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=4000
x = data212[data212.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^12')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=6000
x = data212[data212.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^12')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=8000
x = data212[data212.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^12')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=10000
x = data212[data212.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^12')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=2000
x = data212[data218.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^18')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=4000
x = data212[data218.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^18')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=6000
x = data212[data218.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^18')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=8000
x = data212[data218.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^18')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
plt.figure(figsize=(16,5))
bsize=10000
x = data212[data218.batch_size == bsize]
sns.lineplot(x.batch_no,x.accuracy,data=x,hue=x.classifier)
#sns.lineplot(x.batch_no,x.f1_0,data=x,hue=x.classifier)
#plt.plot()
#plt.xticks(rotation=90)
plt.title(f'Batch Size = {bsize} features = 2^18')
#plt.xlabel('Categories')
#plt.ylabel('Total installs')
plt.show()

# %%
accmean212 = class212['accuracy'].agg(np.mean)
plt.figure(figsize=(16,5))
plt.plot(accmean212)
plt.show()

# %%
accmean212
# Out:
# batch_size
# 2000     0.724034
# 4000     0.715938
# 6000     0.711178
# 8000     0.708288
# 10000    0.706867
# Name: accuracy, dtype: float64

# %%
accmean212 = class212['accuracy'].agg(np.mean)
plt.figure(figsize=(16,5))
sns.lineplot(data=accmean212,hue=a.classifier)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-68936b8835bb> in <module>
#       1 accmean212 = class212['accuracy'].agg(np.mean)
#       2 plt.figure(figsize=(16,5))
# ----> 3 sns.lineplot(data=accmean212,hue=accmean212.classifier)
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'classifier'

# %%
exp = data212.groupby(['classifier','batch_size'])

# %%
accmean212 = exp.agg({'accuracy': np.mean})
plt.figure(figsize=(16,5))
plt.plot(accmean212)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-39908a5b6d1d> in <module>
#       1 accmean212 = exp.agg({'accuracy': np.mean})
#       2 plt.figure(figsize=(16,5))
# ----> 3 plt.plot(accmean212)
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
# ...

# %%
exp.head()
# Out:
#       batch_no classifier  accuracy  recall_0  recall_4  precision_0  \
# 0            1         PA    0.6325  0.676190  0.584211     0.642534
# 1            1         NB    0.8075  0.800000  0.815789     0.827586
# 2            1        SGD    0.5925  0.561905  0.626316     0.624339
# 3            2         PA    0.6825  0.715736  0.650246     0.665094
# 4            2         NB    0.8150  0.827411  0.802956     0.802956
# ...        ...        ...       ...       ...       ...          ...
# 4759         4         NB    0.7175  0.698819  0.736789     0.732714
# 4760         4        SGD    0.7085  0.671260  0.746951     0.732546
# 4761         5         PA    0.6885  0.680872  0.696266     0.695344
# 4762         5         NB    0.7145  0.733399  0.695257     0.710173
# 4763         5        SGD    0.6995  0.682854  0.716448     0.710309
#
#       precision_4      f1_0      f1_4  batch_size features
# 0        0.620112  0.658933  0.601626        2000    2**12
# ...

# %%
exp.describe()
# Out:
#                       batch_no                                                 \
#                          count   mean         std  min     25%    50%     75%
# classifier batch_size
# NB         2000          760.0  380.5  219.537392  1.0  190.75  380.5  570.25
#            4000          380.0  190.5  109.840794  1.0   95.75  190.5  285.25
#            6000          253.0  127.0   73.179004  1.0   64.00  127.0  190.00
#            8000          190.0   95.5   54.992424  1.0   48.25   95.5  142.75
#            10000         152.0   76.5   44.022721  1.0   38.75   76.5  114.25
# PA         2000          760.0  380.5  219.537392  1.0  190.75  380.5  570.25
#            4000          380.0  190.5  109.840794  1.0   95.75  190.5  285.25
#            6000          253.0  127.0   73.179004  1.0   64.00  127.0  190.00
#            8000          190.0   95.5   54.992424  1.0   48.25   95.5  142.75
#            10000         152.0   76.5   44.022721  1.0   38.75   76.5  114.25
# ...

# %%
accmean212
# Out:
#                        accuracy
# classifier batch_size
# NB         2000        0.804260
#            4000        0.764974
#            6000        0.746904
#            8000        0.736007
#            10000       0.727836
# PA         2000        0.644072
#            4000        0.658421
#            6000        0.663735
#            8000        0.666059
#            10000       0.669635
# SGD        2000        0.723770
#            4000        0.724418
#            6000        0.722895
#            8000        0.722799
#            10000       0.723132

# %%
exp.head()
# Out:
#       batch_no classifier  accuracy  recall_0  recall_4  precision_0  \
# 0            1         PA    0.6325  0.676190  0.584211     0.642534
# 1            1         NB    0.8075  0.800000  0.815789     0.827586
# 2            1        SGD    0.5925  0.561905  0.626316     0.624339
# 3            2         PA    0.6825  0.715736  0.650246     0.665094
# 4            2         NB    0.8150  0.827411  0.802956     0.802956
# ...        ...        ...       ...       ...       ...          ...
# 4759         4         NB    0.7175  0.698819  0.736789     0.732714
# 4760         4        SGD    0.7085  0.671260  0.746951     0.732546
# 4761         5         PA    0.6885  0.680872  0.696266     0.695344
# 4762         5         NB    0.7145  0.733399  0.695257     0.710173
# 4763         5        SGD    0.6995  0.682854  0.716448     0.710309
#
#       precision_4      f1_0      f1_4  batch_size features
# 0        0.620112  0.658933  0.601626        2000    2**12
# ...

# %%
type(accmean212)
# Out:
# pandas.core.frame.DataFrame

# %%
accmean212.columns
# Out:
# Index(['accuracy'], dtype='object')

# %%
accmean212.accuracy
# Out:
# classifier  batch_size
# NB          2000          0.804260
#             4000          0.764974
#             6000          0.746904
#             8000          0.736007
#             10000         0.727836
# PA          2000          0.644072
#             4000          0.658421
#             6000          0.663735
#             8000          0.666059
#             10000         0.669635
# SGD         2000          0.723770
#             4000          0.724418
#             6000          0.722895
#             8000          0.722799
#             10000         0.723132
# Name: accuracy, dtype: float64

# %%
plt.figure(figsize=(16,5))
plt.plot(accmean212.accuracy)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-1e4f89247af1> in <module>
#       1 plt.figure(figsize=(16,5))
# ----> 2 plt.plot(accmean212.accuracy)
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...

# %%
newexp = data212.groupby(['classifier','batch_size']).agg(meanaccuracy=('accuracy','mean'))
newexp = newexp.reset_index()

# %%
plt.figure(figsize=(16,5))
sns.barplot(x='batch_size',y='meanaccuracy',hue='classifier',data=newexp)

# %%
plt.figure(figsize=(16,5))
sns.lineplot(x='batch_size',y='meanaccuracy',hue='classifier',data=newexp)

# %%
newexp2 = data218.groupby(['classifier','batch_size']).agg(meanaccuracy=('accuracy','mean'))
newexp2 = newexp2.reset_index()
plt.figure(figsize=(16,5))
sns.lineplot(x='batch_size',y='meanaccuracy',hue='classifier',data=newexp2)

# %%
newexp2 = data218.groupby(['classifier','batch_size']).agg(meanaccuracy=('accuracy','mean'))
newexp2 = newexp2.reset_index()
plt.figure(figsize=(16,5))
sns.barplot(x='batch_size',y='meanaccuracy',hue='classifier',data=newexp2)

# %%
for i in range(0,0.5,5):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-5c3fc44fae30> in <module>
# ----> 1 for i in range(0,0.5,5):
#       2     print(i)
#
# TypeError: 'float' object cannot be interpreted as an integer
