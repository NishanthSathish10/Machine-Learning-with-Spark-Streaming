# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv("cluster_data.csv")

# %%
df
# Out:
#        batch_no      pca1      pca2      pca3  y_pred  label
# 0             1  0.086627  0.438616  0.446842       0      1
# 1             1  0.038284  0.079116 -0.070029       0      0
# 2             1  0.046191  0.096839 -0.137898       0      0
# 3             1  0.010846  0.007250 -0.003474       0      1
# 4             1  0.063840  0.095753 -0.118246       0      0
# ...         ...       ...       ...       ...     ...    ...
# 79995        16  0.019318  0.065768  0.040727       0      0
# 79996        16  0.024769  0.014425 -0.002659       0      0
# 79997        16  0.053012  0.138195 -0.183045       0      0
# 79998        16  0.054678  0.281419  0.355438       0      0
# 79999        16  0.047534  0.080913 -0.043226       0      1
#
# [80000 rows x 6 columns]

# %%
batchNo = 1
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
fig = plt.figure(1, figsize=(7,7))
plt.xlabel("pca1")
plt.ylabel("pca2")
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 1')

# %%
batchNo = 2
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
fig = plt.figure(1, figsize=(7,7))
plt.xlabel("pca1")
plt.ylabel("pca2")
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 2')

# %%
batchNo = 3
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 3')

# %%
batchNo = 4
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 4')

# %%
batchNo = 5
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 5')

# %%
batchNo = 6
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 6')

# %%
batchNo = 7
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 7')

# %%
batchNo = 8
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 8')

# %%
batchNo = 9
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 9')

# %%
batchNo = 10
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 10')

# %%
batchNo = 11
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 11')

# %%
batchNo = 12
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 12')

# %%
batchNo = 13
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 13')

# %%
batchNo = 14
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 14')

# %%
batchNo = 15
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 15')

# %%
batchNo = 16
temp = df[df.batch_no == batchNo]
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title(f"Batch No : {batchNo}", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title(f"Batch No : {batchNo}", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Batch No : 16')

# %%
temp = df
fig = plt.figure(0, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['y_pred'], cmap='rainbow')
plt.title("Clustering our model predicted", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
fig = plt.figure(1, figsize=(7,7))
plt.scatter(temp['pca1'], temp['pca2'], c=temp['label'], cmap='rainbow')
plt.title("Reality", fontsize=14)
plt.xlabel("pca1")
plt.ylabel("pca2")
# Out:
# Text(0, 0.5, 'pca2')

# %%
temp = df
fig = plt.figure(0, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['y_pred'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title("Clustering our model predicted", fontsize=14)
fig = plt.figure(1, figsize=(7,7))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
ax.scatter(temp['pca1'],temp['pca2'],temp['pca3'], c=temp['label'], cmap='rainbow')
ax.set_xlabel("pca1")
ax.set_ylabel("pca2")
ax.set_zlabel("pca3")
ax.set_facecolor('white')
plt.title("Reality", fontsize=14)
# Out:
# Text(0.5, 0.92, 'Reality')
